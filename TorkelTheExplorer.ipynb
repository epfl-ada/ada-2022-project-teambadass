# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math

#load the statistical libraries
from statsmodels.stats import diagnostic
from scipy import stats

# %%
data_folder = './data/'
movies = pd.read_table(data_folder + 'movie.metadata.tsv',names=['wiki_id','freebase_id','name','release_date','box_office_revenue','length','language','country','genre'])

# %%
movies
# Out:
#         wiki_id freebase_id  \
# 0        975900   /m/03vyhn
# 1       3196793   /m/08yl5d
# 2      28463795  /m/0crgdbh
# 3       9363483  /m/0285_cd
# 4        261236   /m/01mrr1
# ...         ...         ...
# 81736  35228177  /m/0j7hxnt
# 81737  34980460  /m/0g4pl34
# 81738   9971909  /m/02pygw1
# 81739    913762   /m/03pcrp
# 81740  12476867  /m/02w7zz8
#
#                                                     name release_date  \
# 0                                         Ghosts of Mars   2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16
# 2                                            Brun bitter         1988
# 3                                       White Of The Eye         1987
# 4                                      A Woman in Flames         1983
# ...                                                  ...          ...
# 81736                           Mermaids: The Body Found   2011-03-19
# ...

# %%
movies['box_office_revenue'].hist(bins=30, log=True, range=(0, 1e9))
# Out:
# <AxesSubplot:>

# %%
movies['length'].hist(bins=30, range=(0,200), log=True)
# Out:
# <AxesSubplot:>

# %%
# Revenue vs runtime
fig, ax = plt.subplots()
ax = sns.scatterplot(x=movies['length'], y=movies['box_office_revenue'], ax=ax)
ax.set_xlim(0, 200)
ax.set_ylim(0, 1.1e9)
plt.show()
